# %%
import itertools as it
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.decomposition import KernelPCA
from sklearn.manifold import TSNE
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split

from possibilearn import flatten

rs = 20190105

# %%
import sys
import logging

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# Create STDERR handler
handler_video = logging.StreamHandler(sys.stderr)
# Create file handler
handler_file = logging.FileHandler('axiom-classification.log')

# Create formatter and add it to the handler
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler_video.setFormatter(formatter)
handler_file.setFormatter(formatter)

# Set STDERR handler as the only handler 
logger.handlers = [handler_video, handler_file]

# %%
mu = np.load('mu.npy')

# %%
gram_jaccard = np.load('jaccard_similarity.npy')
dist_jaccard = 1 - gram_jaccard

# %%
dist_length = np.load('length_distance.npy')
gram_length = 1 - dist_length

# %%
dist_leven = np.load('levenshtein_distance.npy')
gram_leven = 1 - dist_leven

# %%
dist_hamming = np.load('hamming_distance.npy')
gram_hamming = 1 - dist_hamming

# %%
def alpha_cut(alpha):
    return lambda x: 1 if x >= alpha else 0


def cut_labels(mu, alpha):
    return np.array(list(map(alpha_cut(alpha), mu)))

# %%
reduced_data_dir = 'data/reduction/'

def learn_experiment(data_matrix,
                     reduction_procedure, reduced_data_filename,
                     mu,
                     learning_algorithm_factory,
                     d=2,
                     alpha_levels=(.2, .4, .5, .75, .9),
                     num_holdouts=5,
                     percentages=(.8, 0, .2),
                     hyperparams_set = {},
                     validation_metric = metrics.accuracy_score,
                     test_metric = metrics.accuracy_score,
                     verbose=False):
    
    # this is to check that any time we have no parameters the validation
    # percentage is 0 and vice versa
    
    assert((hyperparams_set!={} or percentages[1]==0) and \
           (percentages[1]!=0 or hyperparams_set=={}))
    
    hyperparams_iterator = ParameterGrid(hyperparams_set)
    
    
    reduced_data_fullname = reduced_data_dir + reduced_data_filename + '.npy'
    if os.path.isfile(reduced_data_fullname):
        logger.info('Found cached reduced data. Retrieving {}'.format(reduced_data_filename))
        X = np.load(reduced_data_fullname)
    else:
        logger.info('Performing reduction procedure...')
        X = reduction_procedure(n_components=d,
                                random_state=rs).fit_transform(data_matrix)
    
        logger.info('Done!')
        np.save(reduced_data_fullname, X)
        
    label_set = [cut_labels(mu, alpha) for alpha in alpha_levels]
    
    n = len(X)
    assert(n==len(mu))

    ##paired_X = [X[i:i+2] for i in range(0, n, 2)]
    
    best_test_median = float('inf')
    best_test_metric = []
    
    for alpha, y in zip(alpha_levels, label_set):
        
        logger.info('Checking alpha={:.2f}'.format(alpha))
    
        ##paired_y = [y[i:i+2] for i in range(0, n, 2)]

        metric_train = []
        metric_test = []

        for h in range(num_holdouts):
            (X_train,
             X_validate_test,
             y_train,
             y_validate_test) = train_test_split(X, y,
                                                 train_size=percentages[0],
                                                 test_size=1-percentages[0],
                                                 stratify=y)
            
            if percentages[1]==0: # no validation set
                X_validate = []
                X_test = X_validate_test
                y_validate = []
                y_test = y_validate_test
            else:
                val_perc_rel = percentages[1]/(percentages[1]+percentages[2])
                (X_validate,
                 X_test,
                 y_validate,
                 y_test) = train_test_split(X_validate_test, y_validate_test,
                                            train_size=val_perc_rel,
                                            test_size=1-val_perc_rel,
                                            stratify=y_validate_test)

            logger.info('holdout {} of {}'.format(h+1, num_holdouts))
            
            best_hyperparams = {}
            best_err = np.inf
            
            for hyperparams in hyperparams_iterator:
                if not hyperparams:
                    break
                    
                #logger.info('Checking {}'.format(hyperparams))
                
                learning_algorithm = learning_algorithm_factory(**hyperparams)
                learning_algorithm.fit(X_train, y_train)
                y_pred = learning_algorithm.predict(X_validate)
                error = validation_metric(y_validate, y_pred)
                if error < best_err:
                    best_err = error
                    best_hyperparams = hyperparams
            
            logger.info('Learning with best '
                        'hyperparams: {}'.format(best_hyperparams))
            learning_algorithm = learning_algorithm_factory(**best_hyperparams)
            if percentages[1] == 0: # no validation set
                X_train_val = X_train
                y_train_val = y_train
            else:
                X_train_val = np.vstack([X_train, X_validate])
                y_train_val = np.hstack([y_train, y_validate])
            assert(len(X_train_val) == len(X_train) + len(X_validate))
            assert(len(y_train_val) == len(y_train) + len(y_validate))
            learning_algorithm.fit(X_train_val, y_train_val)
            pred_train = learning_algorithm.predict(X_train_val)
            pred_test = learning_algorithm.predict(X_test)
            
            metric_train.append(test_metric(y_train_val, pred_train))
            metric_test.append(test_metric(y_test, pred_test))
        
        test_median = np.median(metric_test)
        if test_median < best_test_median:
            best_test_median = test_median
            best_test_metric = [alpha,
                                np.mean(metric_train),
                                np.median(metric_train),
                                np.std(metric_train),
                                np.mean(metric_test),
                                test_median,
                                np.std(metric_test)]
    names = ['alpha',
             'train_mean', 'train_median', 'train_std',
             'test_mean','test_median', 'test_std']
    return dict(zip(names, best_test_metric))

# %%
def SVC_custom(*args, **kwargs):
    return SVC(*args, **kwargs, max_iter=5000)

from sklearn.preprocessing import MinMaxScaler
        
class ScaledSVC:
    def __init__(self, *args, **kwargs):
        self.svc = SVC(*args, **kwargs, max_iter=5000)
        self.scaler = MinMaxScaler()
    
    def fit(self, X, y):
        self.scaler.fit(X)
        return self.svc.fit(self.scaler.transform(X), y)
    
    def predict(self, X):
        self.scaler.fit(X)
        return self.svc.predict(self.scaler.transform(X))

def RandomForestClassifier_custom(*args, **kwargs):
    return RandomForestClassifier(*args, **kwargs, n_estimators=100)

def MLPClassifier_custom(*args, **kwargs):
    return MLPClassifier(*args, **kwargs, max_iter=5000)

# %%
import json
import os

result_dir = './data/classification/'

# %%
# considered learning algorithms
names = ['Decision tree', 'Random forest', 'Naive Bayes', 'LDA', 'MLP',
         'SVC (linear)', 'SVC (gaussian)']
algorithms = [DecisionTreeClassifier, RandomForestClassifier,
              GaussianNB, LinearDiscriminantAnalysis, MLPClassifier_custom,
              ScaledSVC, ScaledSVC]
hyperp_sets = [{'criterion': ['gini', 'entropy'], 'max_leaf_nodes': [None, 2, 5, 10, 50, 100],
                'max_features': [None, 'sqrt', 'log2'], 'max_depth': [None, 2, 5, 10]},
               {'n_estimators': [5, 10, 50, 100, 200], 'criterion': ['gini', 'entropy'], 'max_leaf_nodes': [None, 2, 5, 10, 50, 100],
                'max_features': [None, 'sqrt', 'log2'], 'max_depth': [None, 2, 5, 10]},
               {}, {}, {'hidden_layer_sizes': [[2], [4], [6], [10], [20]]},
               {'C': [.001, .01, .1, 1, 10], 'kernel': ['linear']},
               {'C': [.001, .01, .1, 1, 10], 'kernel': ['rbf'], 'gamma': [.001, .01, .1, 1, 10, 30]}]
percentages = [(.8, .1, .1), (.8, .1, .2), (.8, 0, .2), (.8, 0, .2),
               (.8, .1, .1),(.8, .1, .1), (.8, .1, .1)]

# considered data matrices
data_names = ['hamming', 'jaccard', 'length', 'levenshtein']
data_matrices = [gram_hamming, gram_jaccard, gram_length, gram_leven]

# considered number of extracted components
components = [2, 3, 5, 10, 30]

# %%
num_experiments = len(algorithms) *  len(data_matrices) *  len(components)

learning_procedures = zip(names, algorithms, hyperp_sets, percentages)

data = zip(data_names, data_matrices)

experiments = it.product(learning_procedures, data, components)

performed_experiments = 0

re_generate_files = False
append = True

num_groups = 10
for g in range(num_groups):
    logger.info('Started experiment group {} of {}'.format(g+1, num_groups))
    for experiment in experiments:
        learning_procedure = experiment[0]
        data_item = experiment[1]
        comp = experiment[2]
        out_file = result_dir + 'class-' + \
                   learning_procedure[0].replace(' ', '_') + '-' + \
                   'pca-' + \
                   data_item[0] + '-' + \
                   str(comp) + '.json'
        logger.info('Considering {}'.format(out_file))
        if os.path.isfile(out_file) and not re_generate_files and not append:
            logger.info('already exists, skipping')
        else:
            access_flag = 'w' if not append else 'a'
            if append:
                logger.info('appending to existing file')
            elif re_generate_files:
                logger.info('re-executing experiment')
            else:
                logger.info('does not exist, starting experiment')
            # perform experiment
            res = learn_experiment(data_item[1],
                                   KernelPCA, 'PCA-' + experiment[1][0],
                                   mu,
                                   learning_procedure[1],
                                   d=comp,
                                   alpha_levels=(.2, .4, .5, .6, .8, .9),
                                   percentages=learning_procedure[3],
                                   hyperparams_set = learning_procedure[2])
            
            if access_flag == 'a':
                logger.info('opening result file in append')
            else:
                logger.info('creating result file')
            with open(out_file, access_flag) as f:
                f.write('\n')
                json.dump(res, f)

            logger.info('experiment finished')
        performed_experiments += 1
        perc_complete = 100 * performed_experiments / num_experiments
        logger.info('completed {:.2f}%'.format(perc_complete))
    logger.info('Ended experiment group {} of {}'.format(g+1, num_groups))
# Out:
# 2020-01-24 16:49:27,286 - INFO - Started experiment group 1 of 10
# 2020-01-24 16:49:27,287 - INFO - Considering ./data/classification/class-Decision_tree-pca-hamming-2.json
# 2020-01-24 16:49:27,288 - INFO - appending to existing file
# 2020-01-24 16:49:27,288 - INFO - Found cached reduced data. Retrieving PCA-hamming
# 2020-01-24 16:49:27,297 - INFO - Checking alpha=0.20
# 2020-01-24 16:49:27,303 - INFO - holdout 1 of 5
# 2020-01-24 16:49:27,483 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:27,487 - INFO - holdout 2 of 5
# 2020-01-24 16:49:27,653 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:27,657 - INFO - holdout 3 of 5
# 2020-01-24 16:49:27,847 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:27,851 - INFO - holdout 4 of 5
# 2020-01-24 16:49:28,053 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50}
# 2020-01-24 16:49:28,057 - INFO - holdout 5 of 5
# 2020-01-24 16:49:28,241 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:28,247 - INFO - Checking alpha=0.40
# 2020-01-24 16:49:28,250 - INFO - holdout 1 of 5
# 2020-01-24 16:49:28,422 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None}
# 2020-01-24 16:49:28,426 - INFO - holdout 2 of 5
# 2020-01-24 16:49:28,603 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:28,609 - INFO - holdout 3 of 5
# 2020-01-24 16:49:28,781 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:28,786 - INFO - holdout 4 of 5
# 2020-01-24 16:49:28,951 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 10}
# 2020-01-24 16:49:28,956 - INFO - holdout 5 of 5
# 2020-01-24 16:49:29,172 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:29,175 - INFO - Checking alpha=0.50
# 2020-01-24 16:49:29,179 - INFO - holdout 1 of 5
# 2020-01-24 16:49:29,374 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:29,378 - INFO - holdout 2 of 5
# 2020-01-24 16:49:29,540 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:29,544 - INFO - holdout 3 of 5
# 2020-01-24 16:49:29,710 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 5}
# 2020-01-24 16:49:29,715 - INFO - holdout 4 of 5
# 2020-01-24 16:49:29,878 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:29,883 - INFO - holdout 5 of 5
# 2020-01-24 16:49:30,104 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:30,109 - INFO - Checking alpha=0.60
# 2020-01-24 16:49:30,113 - INFO - holdout 1 of 5
# 2020-01-24 16:49:30,344 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:30,350 - INFO - holdout 2 of 5
# 2020-01-24 16:49:30,528 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 10}
# 2020-01-24 16:49:30,533 - INFO - holdout 3 of 5
# 2020-01-24 16:49:30,770 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:30,774 - INFO - holdout 4 of 5
# 2020-01-24 16:49:30,943 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:30,948 - INFO - holdout 5 of 5
# 2020-01-24 16:49:31,148 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:31,150 - INFO - Checking alpha=0.80
# 2020-01-24 16:49:31,155 - INFO - holdout 1 of 5
# 2020-01-24 16:49:31,369 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:31,376 - INFO - holdout 2 of 5
# 2020-01-24 16:49:31,545 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:31,549 - INFO - holdout 3 of 5
# 2020-01-24 16:49:31,717 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:31,721 - INFO - holdout 4 of 5
# 2020-01-24 16:49:31,886 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:31,889 - INFO - holdout 5 of 5
# 2020-01-24 16:49:32,051 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:32,053 - INFO - Checking alpha=0.90
# 2020-01-24 16:49:32,056 - INFO - holdout 1 of 5
# 2020-01-24 16:49:32,314 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:32,320 - INFO - holdout 2 of 5
# 2020-01-24 16:49:32,513 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5}
# 2020-01-24 16:49:32,517 - INFO - holdout 3 of 5
# 2020-01-24 16:49:32,690 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:32,694 - INFO - holdout 4 of 5
# 2020-01-24 16:49:32,858 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:32,861 - INFO - holdout 5 of 5
# 2020-01-24 16:49:33,032 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:33,034 - INFO - opening result file in append
# 2020-01-24 16:49:33,035 - INFO - experiment finished
# 2020-01-24 16:49:33,035 - INFO - completed 0.71%
# 2020-01-24 16:49:33,036 - INFO - Considering ./data/classification/class-Decision_tree-pca-hamming-3.json
# 2020-01-24 16:49:33,037 - INFO - appending to existing file
# 2020-01-24 16:49:33,038 - INFO - Found cached reduced data. Retrieving PCA-hamming
# 2020-01-24 16:49:33,041 - INFO - Checking alpha=0.20
# 2020-01-24 16:49:33,045 - INFO - holdout 1 of 5
# 2020-01-24 16:49:33,211 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:33,214 - INFO - holdout 2 of 5
# 2020-01-24 16:49:33,381 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10}
# 2020-01-24 16:49:33,385 - INFO - holdout 3 of 5
# 2020-01-24 16:49:33,554 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:33,557 - INFO - holdout 4 of 5
# 2020-01-24 16:49:33,734 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:33,738 - INFO - holdout 5 of 5
# 2020-01-24 16:49:33,971 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 10}
# 2020-01-24 16:49:33,974 - INFO - Checking alpha=0.40
# 2020-01-24 16:49:33,976 - INFO - holdout 1 of 5
# 2020-01-24 16:49:34,153 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None}
# 2020-01-24 16:49:34,158 - INFO - holdout 2 of 5
# 2020-01-24 16:49:34,337 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None}
# 2020-01-24 16:49:34,342 - INFO - holdout 3 of 5
# 2020-01-24 16:49:34,521 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:34,526 - INFO - holdout 4 of 5
# 2020-01-24 16:49:34,732 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:34,736 - INFO - holdout 5 of 5
# 2020-01-24 16:49:34,913 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 5}
# 2020-01-24 16:49:34,916 - INFO - Checking alpha=0.50
# 2020-01-24 16:49:34,919 - INFO - holdout 1 of 5
# 2020-01-24 16:49:35,105 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:35,109 - INFO - holdout 2 of 5
# 2020-01-24 16:49:35,276 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:35,280 - INFO - holdout 3 of 5
# 2020-01-24 16:49:35,517 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:35,522 - INFO - holdout 4 of 5
# 2020-01-24 16:49:35,784 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:35,791 - INFO - holdout 5 of 5
# 2020-01-24 16:49:35,976 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:35,978 - INFO - Checking alpha=0.60
# 2020-01-24 16:49:35,981 - INFO - holdout 1 of 5
# 2020-01-24 16:49:36,152 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:36,156 - INFO - holdout 2 of 5
# 2020-01-24 16:49:36,326 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 10}
# 2020-01-24 16:49:36,330 - INFO - holdout 3 of 5
# 2020-01-24 16:49:36,497 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:36,502 - INFO - holdout 4 of 5
# 2020-01-24 16:49:36,737 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:36,742 - INFO - holdout 5 of 5
# 2020-01-24 16:49:36,985 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:36,987 - INFO - Checking alpha=0.80
# 2020-01-24 16:49:36,990 - INFO - holdout 1 of 5
# 2020-01-24 16:49:37,224 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:37,232 - INFO - holdout 2 of 5
# 2020-01-24 16:49:37,457 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10}
# 2020-01-24 16:49:37,461 - INFO - holdout 3 of 5
# 2020-01-24 16:49:37,642 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:37,646 - INFO - holdout 4 of 5
# 2020-01-24 16:49:37,824 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:37,827 - INFO - holdout 5 of 5
# 2020-01-24 16:49:38,013 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:38,015 - INFO - Checking alpha=0.90
# 2020-01-24 16:49:38,018 - INFO - holdout 1 of 5
# 2020-01-24 16:49:38,239 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:38,243 - INFO - holdout 2 of 5
# 2020-01-24 16:49:38,424 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:38,428 - INFO - holdout 3 of 5
# 2020-01-24 16:49:38,605 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:38,609 - INFO - holdout 4 of 5
# 2020-01-24 16:49:38,787 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2}
# 2020-01-24 16:49:38,791 - INFO - holdout 5 of 5
# 2020-01-24 16:49:39,034 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:39,037 - INFO - opening result file in append
# 2020-01-24 16:49:39,038 - INFO - experiment finished
# 2020-01-24 16:49:39,039 - INFO - completed 1.43%
# 2020-01-24 16:49:39,040 - INFO - Considering ./data/classification/class-Decision_tree-pca-hamming-5.json
# 2020-01-24 16:49:39,041 - INFO - appending to existing file
# 2020-01-24 16:49:39,041 - INFO - Found cached reduced data. Retrieving PCA-hamming
# 2020-01-24 16:49:39,050 - INFO - Checking alpha=0.20
# 2020-01-24 16:49:39,056 - INFO - holdout 1 of 5
# 2020-01-24 16:49:39,254 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:39,258 - INFO - holdout 2 of 5
# 2020-01-24 16:49:39,445 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:39,449 - INFO - holdout 3 of 5
# 2020-01-24 16:49:39,675 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:39,679 - INFO - holdout 4 of 5
# 2020-01-24 16:49:39,859 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:39,865 - INFO - holdout 5 of 5
# 2020-01-24 16:49:40,081 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:40,084 - INFO - Checking alpha=0.40
# 2020-01-24 16:49:40,088 - INFO - holdout 1 of 5
# 2020-01-24 16:49:40,268 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:40,272 - INFO - holdout 2 of 5
# 2020-01-24 16:49:40,467 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:40,471 - INFO - holdout 3 of 5
# 2020-01-24 16:49:40,650 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5}
# 2020-01-24 16:49:40,655 - INFO - holdout 4 of 5
# 2020-01-24 16:49:40,841 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:40,845 - INFO - holdout 5 of 5
# 2020-01-24 16:49:41,031 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2020-01-24 16:49:41,034 - INFO - Checking alpha=0.50
# 2020-01-24 16:49:41,036 - INFO - holdout 1 of 5
# 2020-01-24 16:49:41,212 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:41,216 - INFO - holdout 2 of 5
# 2020-01-24 16:49:41,426 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2020-01-24 16:49:41,430 - INFO - holdout 3 of 5
# 2020-01-24 16:49:41,609 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:41,614 - INFO - holdout 4 of 5
# 2020-01-24 16:49:41,797 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None}
# 2020-01-24 16:49:41,802 - INFO - holdout 5 of 5
# 2020-01-24 16:49:41,982 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:41,984 - INFO - Checking alpha=0.60
# 2020-01-24 16:49:41,988 - INFO - holdout 1 of 5
# 2020-01-24 16:49:42,181 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 10}
# 2020-01-24 16:49:42,187 - INFO - holdout 2 of 5
# 2020-01-24 16:49:42,360 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 10}
# 2020-01-24 16:49:42,364 - INFO - holdout 3 of 5
# 2020-01-24 16:49:42,550 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:42,554 - INFO - holdout 4 of 5
# 2020-01-24 16:49:42,734 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2020-01-24 16:49:42,738 - INFO - holdout 5 of 5
# 2020-01-24 16:49:42,920 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:42,922 - INFO - Checking alpha=0.80
# 2020-01-24 16:49:42,925 - INFO - holdout 1 of 5
# 2020-01-24 16:49:43,103 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:43,107 - INFO - holdout 2 of 5
# 2020-01-24 16:49:43,294 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:43,298 - INFO - holdout 3 of 5
# 2020-01-24 16:49:43,480 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:43,484 - INFO - holdout 4 of 5
# 2020-01-24 16:49:43,662 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:43,666 - INFO - holdout 5 of 5
# 2020-01-24 16:49:43,835 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:43,837 - INFO - Checking alpha=0.90
# 2020-01-24 16:49:43,839 - INFO - holdout 1 of 5
# 2020-01-24 16:49:44,015 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:44,020 - INFO - holdout 2 of 5
# 2020-01-24 16:49:44,193 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:44,198 - INFO - holdout 3 of 5
# 2020-01-24 16:49:44,370 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2}
# 2020-01-24 16:49:44,374 - INFO - holdout 4 of 5
# 2020-01-24 16:49:44,570 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:44,574 - INFO - holdout 5 of 5
# 2020-01-24 16:49:44,755 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:44,757 - INFO - opening result file in append
# 2020-01-24 16:49:44,758 - INFO - experiment finished
# 2020-01-24 16:49:44,759 - INFO - completed 2.14%
# 2020-01-24 16:49:44,760 - INFO - Considering ./data/classification/class-Decision_tree-pca-hamming-10.json
# 2020-01-24 16:49:44,760 - INFO - appending to existing file
# 2020-01-24 16:49:44,761 - INFO - Found cached reduced data. Retrieving PCA-hamming
# 2020-01-24 16:49:44,765 - INFO - Checking alpha=0.20
# 2020-01-24 16:49:44,768 - INFO - holdout 1 of 5
# 2020-01-24 16:49:44,954 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:44,959 - INFO - holdout 2 of 5
# 2020-01-24 16:49:45,144 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:45,148 - INFO - holdout 3 of 5
# 2020-01-24 16:49:45,336 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:45,340 - INFO - holdout 4 of 5
# 2020-01-24 16:49:45,523 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:45,528 - INFO - holdout 5 of 5
# 2020-01-24 16:49:45,715 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:45,717 - INFO - Checking alpha=0.40
# 2020-01-24 16:49:45,721 - INFO - holdout 1 of 5
# 2020-01-24 16:49:45,926 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:45,931 - INFO - holdout 2 of 5
# 2020-01-24 16:49:46,116 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:46,120 - INFO - holdout 3 of 5
# 2020-01-24 16:49:46,302 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:46,306 - INFO - holdout 4 of 5
# 2020-01-24 16:49:46,480 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:46,484 - INFO - holdout 5 of 5
# 2020-01-24 16:49:46,653 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:46,655 - INFO - Checking alpha=0.50
# 2020-01-24 16:49:46,657 - INFO - holdout 1 of 5
# 2020-01-24 16:49:46,830 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:46,834 - INFO - holdout 2 of 5
# 2020-01-24 16:49:47,003 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:47,007 - INFO - holdout 3 of 5
# 2020-01-24 16:49:47,174 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 10}
# 2020-01-24 16:49:47,177 - INFO - holdout 4 of 5
# 2020-01-24 16:49:47,347 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:47,351 - INFO - holdout 5 of 5
# 2020-01-24 16:49:47,525 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:47,526 - INFO - Checking alpha=0.60
# 2020-01-24 16:49:47,529 - INFO - holdout 1 of 5
# 2020-01-24 16:49:47,703 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:47,706 - INFO - holdout 2 of 5
# 2020-01-24 16:49:47,873 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:47,876 - INFO - holdout 3 of 5
# 2020-01-24 16:49:48,047 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:48,050 - INFO - holdout 4 of 5
# 2020-01-24 16:49:48,220 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10}
# 2020-01-24 16:49:48,224 - INFO - holdout 5 of 5
# 2020-01-24 16:49:48,398 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:48,401 - INFO - Checking alpha=0.80
# 2020-01-24 16:49:48,403 - INFO - holdout 1 of 5
# 2020-01-24 16:49:48,589 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:48,593 - INFO - holdout 2 of 5
# 2020-01-24 16:49:48,772 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:48,776 - INFO - holdout 3 of 5
# 2020-01-24 16:49:48,959 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:48,963 - INFO - holdout 4 of 5
# 2020-01-24 16:49:49,146 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:49,150 - INFO - holdout 5 of 5
# 2020-01-24 16:49:49,335 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:49,337 - INFO - Checking alpha=0.90
# 2020-01-24 16:49:49,340 - INFO - holdout 1 of 5
# 2020-01-24 16:49:49,534 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:49,538 - INFO - holdout 2 of 5
# 2020-01-24 16:49:49,734 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100}
# 2020-01-24 16:49:49,738 - INFO - holdout 3 of 5
# 2020-01-24 16:49:49,936 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:49,942 - INFO - holdout 4 of 5
# 2020-01-24 16:49:50,148 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2}
# 2020-01-24 16:49:50,152 - INFO - holdout 5 of 5
# 2020-01-24 16:49:50,352 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:50,354 - INFO - opening result file in append
# 2020-01-24 16:49:50,355 - INFO - experiment finished
# 2020-01-24 16:49:50,356 - INFO - completed 2.86%
# 2020-01-24 16:49:50,357 - INFO - Considering ./data/classification/class-Decision_tree-pca-hamming-30.json
# 2020-01-24 16:49:50,358 - INFO - appending to existing file
# 2020-01-24 16:49:50,359 - INFO - Found cached reduced data. Retrieving PCA-hamming
# 2020-01-24 16:49:50,364 - INFO - Checking alpha=0.20
# 2020-01-24 16:49:50,367 - INFO - holdout 1 of 5
# 2020-01-24 16:49:50,559 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:50,564 - INFO - holdout 2 of 5
# 2020-01-24 16:49:50,757 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None}
# 2020-01-24 16:49:50,762 - INFO - holdout 3 of 5
# 2020-01-24 16:49:50,944 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:50,948 - INFO - holdout 4 of 5
# 2020-01-24 16:49:51,125 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:51,128 - INFO - holdout 5 of 5
# 2020-01-24 16:49:51,365 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:51,368 - INFO - Checking alpha=0.40
# 2020-01-24 16:49:51,373 - INFO - holdout 1 of 5
# 2020-01-24 16:49:51,570 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:51,574 - INFO - holdout 2 of 5
# 2020-01-24 16:49:51,754 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2020-01-24 16:49:51,758 - INFO - holdout 3 of 5
# 2020-01-24 16:49:51,933 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None}
# 2020-01-24 16:49:51,937 - INFO - holdout 4 of 5
# 2020-01-24 16:49:52,118 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:52,122 - INFO - holdout 5 of 5
# 2020-01-24 16:49:52,302 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:52,304 - INFO - Checking alpha=0.50
# 2020-01-24 16:49:52,306 - INFO - holdout 1 of 5
# 2020-01-24 16:49:52,484 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:52,489 - INFO - holdout 2 of 5
# 2020-01-24 16:49:52,684 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:52,689 - INFO - holdout 3 of 5
# 2020-01-24 16:49:52,886 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:52,890 - INFO - holdout 4 of 5
# 2020-01-24 16:49:53,095 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:53,100 - INFO - holdout 5 of 5
# 2020-01-24 16:49:53,338 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:53,341 - INFO - Checking alpha=0.60
# 2020-01-24 16:49:53,345 - INFO - holdout 1 of 5
# 2020-01-24 16:49:53,556 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:53,561 - INFO - holdout 2 of 5
# 2020-01-24 16:49:53,766 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None}
# 2020-01-24 16:49:53,770 - INFO - holdout 3 of 5
# 2020-01-24 16:49:53,972 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:53,977 - INFO - holdout 4 of 5
# 2020-01-24 16:49:54,169 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:54,174 - INFO - holdout 5 of 5
# 2020-01-24 16:49:54,360 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:54,363 - INFO - Checking alpha=0.80
# 2020-01-24 16:49:54,365 - INFO - holdout 1 of 5
# 2020-01-24 16:49:54,557 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:54,561 - INFO - holdout 2 of 5
# 2020-01-24 16:49:54,763 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:54,767 - INFO - holdout 3 of 5
# 2020-01-24 16:49:54,972 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:54,976 - INFO - holdout 4 of 5
# 2020-01-24 16:49:55,178 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:55,182 - INFO - holdout 5 of 5
# 2020-01-24 16:49:55,409 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:55,411 - INFO - Checking alpha=0.90
# 2020-01-24 16:49:55,414 - INFO - holdout 1 of 5
# 2020-01-24 16:49:55,660 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 5}
# 2020-01-24 16:49:55,665 - INFO - holdout 2 of 5
# 2020-01-24 16:49:55,892 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:55,899 - INFO - holdout 3 of 5
# 2020-01-24 16:49:56,112 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:56,119 - INFO - holdout 4 of 5
# 2020-01-24 16:49:56,359 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:56,363 - INFO - holdout 5 of 5
# 2020-01-24 16:49:56,589 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:56,591 - INFO - opening result file in append
# 2020-01-24 16:49:56,592 - INFO - experiment finished
# 2020-01-24 16:49:56,592 - INFO - completed 3.57%
# 2020-01-24 16:49:56,593 - INFO - Considering ./data/classification/class-Decision_tree-pca-jaccard-2.json
# 2020-01-24 16:49:56,593 - INFO - appending to existing file
# 2020-01-24 16:49:56,594 - INFO - Found cached reduced data. Retrieving PCA-jaccard
# 2020-01-24 16:49:56,598 - INFO - Checking alpha=0.20
# 2020-01-24 16:49:56,602 - INFO - holdout 1 of 5
# 2020-01-24 16:49:56,722 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2020-01-24 16:49:56,726 - INFO - holdout 2 of 5
# 2020-01-24 16:49:56,847 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:56,851 - INFO - holdout 3 of 5
# 2020-01-24 16:49:56,973 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:56,977 - INFO - holdout 4 of 5
# 2020-01-24 16:49:57,099 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:57,103 - INFO - holdout 5 of 5
# 2020-01-24 16:49:57,224 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 50}
# 2020-01-24 16:49:57,226 - INFO - Checking alpha=0.40
# 2020-01-24 16:49:57,229 - INFO - holdout 1 of 5
# 2020-01-24 16:49:57,351 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:57,354 - INFO - holdout 2 of 5
# 2020-01-24 16:49:57,473 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:57,477 - INFO - holdout 3 of 5
# 2020-01-24 16:49:57,599 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:57,603 - INFO - holdout 4 of 5
# 2020-01-24 16:49:57,723 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:57,727 - INFO - holdout 5 of 5
# 2020-01-24 16:49:57,861 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:57,863 - INFO - Checking alpha=0.50
# 2020-01-24 16:49:57,866 - INFO - holdout 1 of 5
# 2020-01-24 16:49:58,052 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:58,060 - INFO - holdout 2 of 5
# 2020-01-24 16:49:58,216 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:58,221 - INFO - holdout 3 of 5
# 2020-01-24 16:49:58,357 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:58,361 - INFO - holdout 4 of 5
# 2020-01-24 16:49:58,488 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:58,492 - INFO - holdout 5 of 5
# 2020-01-24 16:49:58,653 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:58,657 - INFO - Checking alpha=0.60
# 2020-01-24 16:49:58,661 - INFO - holdout 1 of 5
# 2020-01-24 16:49:58,839 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 10}
# 2020-01-24 16:49:58,845 - INFO - holdout 2 of 5
# 2020-01-24 16:49:59,031 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:59,036 - INFO - holdout 3 of 5
# 2020-01-24 16:49:59,166 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:59,170 - INFO - holdout 4 of 5
# 2020-01-24 16:49:59,330 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:59,336 - INFO - holdout 5 of 5
# 2020-01-24 16:49:59,491 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:59,493 - INFO - Checking alpha=0.80
# 2020-01-24 16:49:59,496 - INFO - holdout 1 of 5
# 2020-01-24 16:49:59,635 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:59,639 - INFO - holdout 2 of 5
# 2020-01-24 16:49:59,780 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:59,784 - INFO - holdout 3 of 5
# 2020-01-24 16:49:59,921 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:49:59,925 - INFO - holdout 4 of 5
# 2020-01-24 16:50:00,064 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:00,068 - INFO - holdout 5 of 5
# 2020-01-24 16:50:00,217 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:00,221 - INFO - Checking alpha=0.90
# 2020-01-24 16:50:00,226 - INFO - holdout 1 of 5
# 2020-01-24 16:50:00,433 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:00,441 - INFO - holdout 2 of 5
# 2020-01-24 16:50:00,606 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:00,611 - INFO - holdout 3 of 5
# 2020-01-24 16:50:00,771 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:00,775 - INFO - holdout 4 of 5
# 2020-01-24 16:50:00,925 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:00,929 - INFO - holdout 5 of 5
# 2020-01-24 16:50:01,076 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:01,078 - INFO - opening result file in append
# 2020-01-24 16:50:01,079 - INFO - experiment finished
# 2020-01-24 16:50:01,080 - INFO - completed 4.29%
# 2020-01-24 16:50:01,080 - INFO - Considering ./data/classification/class-Decision_tree-pca-jaccard-3.json
# 2020-01-24 16:50:01,081 - INFO - appending to existing file
# 2020-01-24 16:50:01,081 - INFO - Found cached reduced data. Retrieving PCA-jaccard
# 2020-01-24 16:50:01,086 - INFO - Checking alpha=0.20
# 2020-01-24 16:50:01,089 - INFO - holdout 1 of 5
# 2020-01-24 16:50:01,234 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:01,238 - INFO - holdout 2 of 5
# 2020-01-24 16:50:01,391 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:01,396 - INFO - holdout 3 of 5
# 2020-01-24 16:50:01,590 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:01,596 - INFO - holdout 4 of 5
# 2020-01-24 16:50:01,778 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:01,782 - INFO - holdout 5 of 5
# 2020-01-24 16:50:01,971 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:01,976 - INFO - Checking alpha=0.40
# 2020-01-24 16:50:01,980 - INFO - holdout 1 of 5
# 2020-01-24 16:50:02,144 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:02,149 - INFO - holdout 2 of 5
# 2020-01-24 16:50:02,303 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:02,308 - INFO - holdout 3 of 5
# 2020-01-24 16:50:02,461 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:02,466 - INFO - holdout 4 of 5
# 2020-01-24 16:50:02,617 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:02,623 - INFO - holdout 5 of 5
# 2020-01-24 16:50:02,783 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:02,787 - INFO - Checking alpha=0.50
# 2020-01-24 16:50:02,792 - INFO - holdout 1 of 5
# 2020-01-24 16:50:02,955 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:02,962 - INFO - holdout 2 of 5
# 2020-01-24 16:50:03,145 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:03,150 - INFO - holdout 3 of 5
# 2020-01-24 16:50:03,308 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:03,313 - INFO - holdout 4 of 5
# 2020-01-24 16:50:03,501 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:03,506 - INFO - holdout 5 of 5
# 2020-01-24 16:50:03,668 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:03,670 - INFO - Checking alpha=0.60
# 2020-01-24 16:50:03,676 - INFO - holdout 1 of 5
# 2020-01-24 16:50:03,825 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:03,830 - INFO - holdout 2 of 5
# 2020-01-24 16:50:04,014 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:04,021 - INFO - holdout 3 of 5
# 2020-01-24 16:50:04,182 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:04,189 - INFO - holdout 4 of 5
# 2020-01-24 16:50:04,337 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:04,343 - INFO - holdout 5 of 5
# 2020-01-24 16:50:04,523 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:04,527 - INFO - Checking alpha=0.80
# 2020-01-24 16:50:04,532 - INFO - holdout 1 of 5
# 2020-01-24 16:50:04,670 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2020-01-24 16:50:04,674 - INFO - holdout 2 of 5
# 2020-01-24 16:50:04,814 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:04,819 - INFO - holdout 3 of 5
# 2020-01-24 16:50:04,991 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:04,996 - INFO - holdout 4 of 5
# 2020-01-24 16:50:05,161 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:05,167 - INFO - holdout 5 of 5
# 2020-01-24 16:50:05,324 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:05,326 - INFO - Checking alpha=0.90
# 2020-01-24 16:50:05,329 - INFO - holdout 1 of 5
# 2020-01-24 16:50:05,483 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:05,488 - INFO - holdout 2 of 5
# 2020-01-24 16:50:05,701 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:05,710 - INFO - holdout 3 of 5
# 2020-01-24 16:50:05,865 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:05,870 - INFO - holdout 4 of 5
# 2020-01-24 16:50:06,037 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:06,042 - INFO - holdout 5 of 5
# 2020-01-24 16:50:06,202 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:06,205 - INFO - opening result file in append
# 2020-01-24 16:50:06,206 - INFO - experiment finished
# 2020-01-24 16:50:06,206 - INFO - completed 5.00%
# 2020-01-24 16:50:06,207 - INFO - Considering ./data/classification/class-Decision_tree-pca-jaccard-5.json
# 2020-01-24 16:50:06,208 - INFO - appending to existing file
# 2020-01-24 16:50:06,208 - INFO - Found cached reduced data. Retrieving PCA-jaccard
# 2020-01-24 16:50:06,213 - INFO - Checking alpha=0.20
# 2020-01-24 16:50:06,217 - INFO - holdout 1 of 5
# 2020-01-24 16:50:06,365 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:06,372 - INFO - holdout 2 of 5
# 2020-01-24 16:50:06,529 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:06,533 - INFO - holdout 3 of 5
# 2020-01-24 16:50:06,689 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:50:06,694 - INFO - holdout 4 of 5
# 2020-01-24 16:50:06,874 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# ...
# 2020-01-24 16:51:06,365 - INFO - holdout 3 of 5
# 2020-01-24 16:51:06,649 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:06,658 - INFO - holdout 4 of 5
# 2020-01-24 16:51:06,933 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2020-01-24 16:51:06,943 - INFO - holdout 5 of 5
# 2020-01-24 16:51:07,235 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:07,238 - INFO - Checking alpha=0.60
# 2020-01-24 16:51:07,245 - INFO - holdout 1 of 5
# 2020-01-24 16:51:07,529 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 100}
# 2020-01-24 16:51:07,538 - INFO - holdout 2 of 5
# 2020-01-24 16:51:07,806 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5}
# 2020-01-24 16:51:07,813 - INFO - holdout 3 of 5
# 2020-01-24 16:51:08,058 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2020-01-24 16:51:08,067 - INFO - holdout 4 of 5
# 2020-01-24 16:51:08,335 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:08,340 - INFO - holdout 5 of 5
# 2020-01-24 16:51:08,606 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:08,609 - INFO - Checking alpha=0.80
# 2020-01-24 16:51:08,613 - INFO - holdout 1 of 5
# 2020-01-24 16:51:08,869 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:08,875 - INFO - holdout 2 of 5
# 2020-01-24 16:51:09,151 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:09,156 - INFO - holdout 3 of 5
# 2020-01-24 16:51:09,419 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2020-01-24 16:51:09,424 - INFO - holdout 4 of 5
# 2020-01-24 16:51:09,686 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5}
# 2020-01-24 16:51:09,692 - INFO - holdout 5 of 5
# 2020-01-24 16:51:09,956 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 10}
# 2020-01-24 16:51:09,960 - INFO - Checking alpha=0.90
# 2020-01-24 16:51:09,964 - INFO - holdout 1 of 5
# 2020-01-24 16:51:10,201 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 10}
# 2020-01-24 16:51:10,206 - INFO - holdout 2 of 5
# 2020-01-24 16:51:10,451 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 5}
# 2020-01-24 16:51:10,455 - INFO - holdout 3 of 5
# 2020-01-24 16:51:10,709 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 50}
# 2020-01-24 16:51:10,714 - INFO - holdout 4 of 5
# 2020-01-24 16:51:10,981 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10}
# 2020-01-24 16:51:10,987 - INFO - holdout 5 of 5
# 2020-01-24 16:51:11,288 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:11,291 - INFO - opening result file in append
# 2020-01-24 16:51:11,293 - INFO - experiment finished
# 2020-01-24 16:51:11,294 - INFO - completed 13.57%
# 2020-01-24 16:51:11,295 - INFO - Considering ./data/classification/class-Decision_tree-pca-levenshtein-30.json
# 2020-01-24 16:51:11,296 - INFO - appending to existing file
# 2020-01-24 16:51:11,298 - INFO - Found cached reduced data. Retrieving PCA-levenshtein
# 2020-01-24 16:51:11,305 - INFO - Checking alpha=0.20
# 2020-01-24 16:51:11,310 - INFO - holdout 1 of 5
# 2020-01-24 16:51:11,596 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:11,601 - INFO - holdout 2 of 5
# 2020-01-24 16:51:11,890 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:11,895 - INFO - holdout 3 of 5
# 2020-01-24 16:51:12,176 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2020-01-24 16:51:12,183 - INFO - holdout 4 of 5
# 2020-01-24 16:51:12,462 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:12,467 - INFO - holdout 5 of 5
# 2020-01-24 16:51:12,737 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:12,741 - INFO - Checking alpha=0.40
# 2020-01-24 16:51:12,744 - INFO - holdout 1 of 5
# 2020-01-24 16:51:13,015 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:13,021 - INFO - holdout 2 of 5
# 2020-01-24 16:51:13,290 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2020-01-24 16:51:13,298 - INFO - holdout 3 of 5
# 2020-01-24 16:51:13,564 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5}
# 2020-01-24 16:51:13,570 - INFO - holdout 4 of 5
# 2020-01-24 16:51:13,851 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:13,856 - INFO - holdout 5 of 5
# 2020-01-24 16:51:14,128 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2020-01-24 16:51:14,131 - INFO - Checking alpha=0.50
# 2020-01-24 16:51:14,135 - INFO - holdout 1 of 5
# 2020-01-24 16:51:14,409 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:14,418 - INFO - holdout 2 of 5
# 2020-01-24 16:51:14,684 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2020-01-24 16:51:14,693 - INFO - holdout 3 of 5
# 2020-01-24 16:51:14,959 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2020-01-24 16:51:14,969 - INFO - holdout 4 of 5
# 2020-01-24 16:51:15,220 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:15,226 - INFO - holdout 5 of 5
# 2020-01-24 16:51:15,485 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:15,488 - INFO - Checking alpha=0.60
# 2020-01-24 16:51:15,491 - INFO - holdout 1 of 5
# 2020-01-24 16:51:15,768 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2020-01-24 16:51:15,776 - INFO - holdout 2 of 5
# 2020-01-24 16:51:16,042 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:16,047 - INFO - holdout 3 of 5
# 2020-01-24 16:51:16,333 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 100}
# 2020-01-24 16:51:16,341 - INFO - holdout 4 of 5
# 2020-01-24 16:51:16,633 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 10}
# 2020-01-24 16:51:16,640 - INFO - holdout 5 of 5
# 2020-01-24 16:51:16,912 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5}
# 2020-01-24 16:51:16,915 - INFO - Checking alpha=0.80
# 2020-01-24 16:51:16,920 - INFO - holdout 1 of 5
# 2020-01-24 16:51:17,161 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:17,166 - INFO - holdout 2 of 5
# 2020-01-24 16:51:17,394 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2020-01-24 16:51:17,399 - INFO - holdout 3 of 5
# 2020-01-24 16:51:17,626 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:17,631 - INFO - holdout 4 of 5
# 2020-01-24 16:51:17,866 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2020-01-24 16:51:17,877 - INFO - holdout 5 of 5
# 2020-01-24 16:51:18,109 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:18,112 - INFO - Checking alpha=0.90
# 2020-01-24 16:51:18,120 - INFO - holdout 1 of 5
# 2020-01-24 16:51:18,359 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:18,364 - INFO - holdout 2 of 5
# 2020-01-24 16:51:18,590 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:18,597 - INFO - holdout 3 of 5
# 2020-01-24 16:51:18,827 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:18,831 - INFO - holdout 4 of 5
# 2020-01-24 16:51:19,064 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 5}
# 2020-01-24 16:51:19,069 - INFO - holdout 5 of 5
# 2020-01-24 16:51:19,314 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2}
# 2020-01-24 16:51:19,317 - INFO - opening result file in append
# 2020-01-24 16:51:19,318 - INFO - experiment finished
# 2020-01-24 16:51:19,318 - INFO - completed 14.29%
# 2020-01-24 16:51:19,319 - INFO - Considering ./data/classification/class-Random_forest-pca-hamming-2.json
# 2020-01-24 16:51:19,320 - INFO - appending to existing file
# 2020-01-24 16:51:19,321 - INFO - Found cached reduced data. Retrieving PCA-hamming
# 2020-01-24 16:51:19,326 - INFO - Checking alpha=0.20
# 2020-01-24 16:51:19,329 - INFO - holdout 1 of 5
# 2020-01-24 16:52:51,207 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2020-01-24 16:52:51,220 - INFO - holdout 2 of 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-50d731f77937> in <module>
#      43                                    alpha_levels=(.2, .4, .5, .6, .8, .9),
#      44                                    percentages=learning_procedure[3],
# ---> 45                                    hyperparams_set = learning_procedure[2])
#      46
#      47             if access_flag == 'a':
#
# <ipython-input-10-5132e3bedf2e> in learn_experiment(data_matrix, reduction_procedure, reduced_data_filename, mu, learning_algorithm_factory, d, alpha_levels, num_holdouts, percentages, hyperparams_set, validation_metric, test_metric, verbose)
#      90
#      91                 learning_algorithm = learning_algorithm_factory(**hyperparams)
# ---> 92                 learning_algorithm.fit(X_train, y_train)
#      93                 y_pred = learning_algorithm.predict(X_validate)
#      94                 error = validation_metric(y_validate, y_pred)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     328                     t, self, X, y, sample_weight, i, len(trees),
#     329                     verbose=self.verbose, class_weight=self.class_weight)
# --> 330                 for i, t in enumerate(trees))
#     331
#     332             # Collect newly grown trees
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     116             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     117
# --> 118         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     119     else:
#     120         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     378                                            min_impurity_split)
#     379
# --> 380         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     381
#     382         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
def TSNE_custom(*args, **kwargs):
    return TSNE(*args, **kwargs, method='exact')



algorithms = [DecisionTreeClassifier, RandomForestClassifier,
              GaussianNB, LinearDiscriminantAnalysis, MLPClassifier_custom,
              ScaledSVC, ScaledSVC]

hyperp_sets = [{'criterion': ['gini', 'entropy'], 'max_leaf_nodes': [None, 2, 5, 10, 50, 100],
                'max_features': [None, 'sqrt', 'log2'], 'max_depth': [None, 2, 5, 10]},
               {'n_estimators': [5, 10, 50, 100, 200], 'criterion': ['gini', 'entropy'], 'max_leaf_nodes': [None, 2, 5, 10, 50, 100],
                'max_features': [None, 'sqrt', 'log2'], 'max_depth': [None, 2, 5, 10]},
               {}, {}, {'hidden_layer_sizes': [[2], [4], [6], [10], [20]]},
               {'C': [.001, .01, .1, 1, 10], 'kernel': ['linear']},
               {'C': [.001, .01, .1, 1, 10], 'kernel': ['rbf'], 'gamma': [.001, .01, .1, 1, 10, 30]}]
percentages = [(.8, .1, .1), (.8, .1, .2), (.8, 0, .2), (.8, 0, .2),
               (.8, .1, .1),(.8, .1, .1), (.8, .1, .1)]


learning_procedures = zip(names, algorithms, hyperp_sets, percentages)

data_matrices = [dist_hamming, dist_jaccard, dist_length, dist_leven]
data = zip(data_names, data_matrices)

experiments = it.product(learning_procedures, data, components)

num_experiments = len(algorithms) *  len(data_matrices) *  len(components)



performed_experiments = 0

re_generate_files = False

append = True

num_groups = 10
for g in range(num_groups):
    logger.info('Started experiment group {} of {}'.format(g+1, num_groups))
    for experiment in experiments:
        learning_procedure = experiment[0]
        data_item = experiment[1]
        comp = experiment[2]
        out_file = result_dir + 'class-' + \
                   learning_procedure[0].replace(' ', '_') + '-' + \
                   'tsne-' + \
                   data_item[0] + '-' + \
                   str(comp) + '.json'
        logger.info('Considering {}'.format(out_file))
        if os.path.isfile(out_file) and not re_generate_files and not append:
            logger.info('already exists, skipping')
        else:
            access_flag = 'w' if not append else 'a'
            if append:
                logger.info('appending to existing file')
            elif re_generate_files:
                logger.info('re-executing experiment')
            else:
                logger.info('does not exist, starting experiment')
            # perform experiment
            res = learn_experiment(data_item[1],
                                   TSNE_custom,  'tsne-' + experiment[1][0],
                                   mu,
                                   learning_procedure[1],
                                   d=comp,
                                   alpha_levels=(.2, .4, .5, .6, .8, .9),
                                   percentages=learning_procedure[3],
                                   hyperparams_set = learning_procedure[2])

            if access_flag == 'a':
                logger.info('opening result file in append')
            else:
                logger.info('creating result file')
            with open(out_file, access_flag) as f:
                f.write('\n')
                json.dump(res, f)

            logger.info('experiment finished')
        performed_experiments += 1
        perc_complete = 100 * performed_experiments / num_experiments
        logger.info('completed {:.2f}%'.format(perc_complete))
    logger.info('Ended experiment group {} of {}'.format(g+1, num_groups))
# Out:
# 2019-06-28 15:25:04,065 - INFO - Considering ./data/classification/class-Decision_tree-tsne-hamming-2.json
# 2019-06-28 15:25:04,066 - INFO - already exists, skipping
# 2019-06-28 15:25:04,067 - INFO - completed 0.71%
# 2019-06-28 15:25:04,068 - INFO - Considering ./data/classification/class-Decision_tree-tsne-hamming-3.json
# 2019-06-28 15:25:04,069 - INFO - already exists, skipping
# 2019-06-28 15:25:04,070 - INFO - completed 1.43%
# 2019-06-28 15:25:04,071 - INFO - Considering ./data/classification/class-Decision_tree-tsne-hamming-5.json
# 2019-06-28 15:25:04,071 - INFO - already exists, skipping
# 2019-06-28 15:25:04,072 - INFO - completed 2.14%
# 2019-06-28 15:25:04,073 - INFO - Considering ./data/classification/class-Decision_tree-tsne-hamming-10.json
# 2019-06-28 15:25:04,073 - INFO - already exists, skipping
# 2019-06-28 15:25:04,074 - INFO - completed 2.86%
# 2019-06-28 15:25:04,075 - INFO - Considering ./data/classification/class-Decision_tree-tsne-hamming-30.json
# 2019-06-28 15:25:04,075 - INFO - already exists, skipping
# 2019-06-28 15:25:04,076 - INFO - completed 3.57%
# 2019-06-28 15:25:04,077 - INFO - Considering ./data/classification/class-Decision_tree-tsne-jaccard-2.json
# 2019-06-28 15:25:04,077 - INFO - already exists, skipping
# 2019-06-28 15:25:04,078 - INFO - completed 4.29%
# 2019-06-28 15:25:04,078 - INFO - Considering ./data/classification/class-Decision_tree-tsne-jaccard-3.json
# 2019-06-28 15:25:04,079 - INFO - already exists, skipping
# 2019-06-28 15:25:04,079 - INFO - completed 5.00%
# 2019-06-28 15:25:04,080 - INFO - Considering ./data/classification/class-Decision_tree-tsne-jaccard-5.json
# 2019-06-28 15:25:04,081 - INFO - already exists, skipping
# 2019-06-28 15:25:04,084 - INFO - completed 5.71%
# 2019-06-28 15:25:04,085 - INFO - Considering ./data/classification/class-Decision_tree-tsne-jaccard-10.json
# 2019-06-28 15:25:04,085 - INFO - already exists, skipping
# 2019-06-28 15:25:04,085 - INFO - completed 6.43%
# 2019-06-28 15:25:04,086 - INFO - Considering ./data/classification/class-Decision_tree-tsne-jaccard-30.json
# 2019-06-28 15:25:04,086 - INFO - already exists, skipping
# 2019-06-28 15:25:04,087 - INFO - completed 7.14%
# 2019-06-28 15:25:04,088 - INFO - Considering ./data/classification/class-Decision_tree-tsne-length-2.json
# 2019-06-28 15:25:04,091 - INFO - does not exist, starting experiment
# 2019-06-28 15:25:04,092 - INFO - Found cached reduced data. Retrieving tsne-length
# 2019-06-28 15:25:04,096 - INFO - Checking alpha=0.20
# 2019-06-28 15:25:04,099 - INFO - holdout 1 of 5
# 2019-06-28 15:25:04,308 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:04,312 - INFO - holdout 2 of 5
# 2019-06-28 15:25:04,459 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:04,464 - INFO - holdout 3 of 5
# 2019-06-28 15:25:04,607 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:04,611 - INFO - holdout 4 of 5
# 2019-06-28 15:25:04,755 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:04,760 - INFO - holdout 5 of 5
# 2019-06-28 15:25:04,933 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:04,939 - INFO - Checking alpha=0.40
# 2019-06-28 15:25:04,942 - INFO - holdout 1 of 5
# 2019-06-28 15:25:05,110 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:05,116 - INFO - holdout 2 of 5
# 2019-06-28 15:25:05,264 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:05,268 - INFO - holdout 3 of 5
# 2019-06-28 15:25:05,535 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:05,542 - INFO - holdout 4 of 5
# 2019-06-28 15:25:05,820 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:05,827 - INFO - holdout 5 of 5
# 2019-06-28 15:25:05,993 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:05,998 - INFO - Checking alpha=0.50
# 2019-06-28 15:25:06,001 - INFO - holdout 1 of 5
# 2019-06-28 15:25:06,165 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:06,174 - INFO - holdout 2 of 5
# 2019-06-28 15:25:06,336 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:06,342 - INFO - holdout 3 of 5
# 2019-06-28 15:25:06,518 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:06,523 - INFO - holdout 4 of 5
# 2019-06-28 15:25:06,690 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 100}
# 2019-06-28 15:25:06,696 - INFO - holdout 5 of 5
# 2019-06-28 15:25:06,872 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:06,876 - INFO - Checking alpha=0.60
# 2019-06-28 15:25:06,879 - INFO - holdout 1 of 5
# 2019-06-28 15:25:07,055 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50}
# 2019-06-28 15:25:07,060 - INFO - holdout 2 of 5
# 2019-06-28 15:25:07,234 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:07,241 - INFO - holdout 3 of 5
# 2019-06-28 15:25:07,403 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 50}
# 2019-06-28 15:25:07,407 - INFO - holdout 4 of 5
# 2019-06-28 15:25:07,566 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:07,572 - INFO - holdout 5 of 5
# 2019-06-28 15:25:07,724 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:07,726 - INFO - Checking alpha=0.80
# 2019-06-28 15:25:07,729 - INFO - holdout 1 of 5
# 2019-06-28 15:25:07,962 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:07,970 - INFO - holdout 2 of 5
# 2019-06-28 15:25:08,192 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:08,200 - INFO - holdout 3 of 5
# 2019-06-28 15:25:08,366 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:08,371 - INFO - holdout 4 of 5
# 2019-06-28 15:25:08,536 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:08,542 - INFO - holdout 5 of 5
# 2019-06-28 15:25:08,702 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:08,705 - INFO - Checking alpha=0.90
# 2019-06-28 15:25:08,707 - INFO - holdout 1 of 5
# 2019-06-28 15:25:08,873 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:08,879 - INFO - holdout 2 of 5
# 2019-06-28 15:25:09,046 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 100}
# 2019-06-28 15:25:09,052 - INFO - holdout 3 of 5
# 2019-06-28 15:25:09,225 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50}
# 2019-06-28 15:25:09,229 - INFO - holdout 4 of 5
# 2019-06-28 15:25:09,404 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:09,410 - INFO - holdout 5 of 5
# 2019-06-28 15:25:09,587 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50}
# 2019-06-28 15:25:09,591 - INFO - experiment finished
# 2019-06-28 15:25:09,592 - INFO - completed 7.86%
# 2019-06-28 15:25:09,592 - INFO - Considering ./data/classification/class-Decision_tree-tsne-length-3.json
# 2019-06-28 15:25:09,592 - INFO - does not exist, starting experiment
# 2019-06-28 15:25:09,593 - INFO - Found cached reduced data. Retrieving tsne-length
# 2019-06-28 15:25:09,596 - INFO - Checking alpha=0.20
# 2019-06-28 15:25:09,599 - INFO - holdout 1 of 5
# 2019-06-28 15:25:09,768 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:09,775 - INFO - holdout 2 of 5
# 2019-06-28 15:25:09,932 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:09,939 - INFO - holdout 3 of 5
# 2019-06-28 15:25:10,083 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 100}
# 2019-06-28 15:25:10,089 - INFO - holdout 4 of 5
# 2019-06-28 15:25:10,242 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 100}
# 2019-06-28 15:25:10,247 - INFO - holdout 5 of 5
# 2019-06-28 15:25:10,406 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:10,410 - INFO - Checking alpha=0.40
# 2019-06-28 15:25:10,413 - INFO - holdout 1 of 5
# 2019-06-28 15:25:10,573 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:10,579 - INFO - holdout 2 of 5
# 2019-06-28 15:25:10,742 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:10,748 - INFO - holdout 3 of 5
# 2019-06-28 15:25:10,908 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:10,914 - INFO - holdout 4 of 5
# 2019-06-28 15:25:11,087 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:11,092 - INFO - holdout 5 of 5
# 2019-06-28 15:25:11,260 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:11,264 - INFO - Checking alpha=0.50
# 2019-06-28 15:25:11,267 - INFO - holdout 1 of 5
# 2019-06-28 15:25:11,438 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:11,447 - INFO - holdout 2 of 5
# 2019-06-28 15:25:11,639 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:11,650 - INFO - holdout 3 of 5
# 2019-06-28 15:25:11,828 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:11,832 - INFO - holdout 4 of 5
# 2019-06-28 15:25:12,006 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:12,011 - INFO - holdout 5 of 5
# 2019-06-28 15:25:12,189 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:12,195 - INFO - Checking alpha=0.60
# 2019-06-28 15:25:12,199 - INFO - holdout 1 of 5
# 2019-06-28 15:25:12,401 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:12,407 - INFO - holdout 2 of 5
# 2019-06-28 15:25:12,576 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 50}
# 2019-06-28 15:25:12,581 - INFO - holdout 3 of 5
# 2019-06-28 15:25:12,752 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:12,758 - INFO - holdout 4 of 5
# 2019-06-28 15:25:12,940 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:12,946 - INFO - holdout 5 of 5
# 2019-06-28 15:25:13,123 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:13,129 - INFO - Checking alpha=0.80
# 2019-06-28 15:25:13,131 - INFO - holdout 1 of 5
# 2019-06-28 15:25:13,309 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:13,313 - INFO - holdout 2 of 5
# 2019-06-28 15:25:13,485 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:13,490 - INFO - holdout 3 of 5
# 2019-06-28 15:25:13,679 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:13,685 - INFO - holdout 4 of 5
# 2019-06-28 15:25:13,897 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:13,903 - INFO - holdout 5 of 5
# 2019-06-28 15:25:14,135 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:14,141 - INFO - Checking alpha=0.90
# 2019-06-28 15:25:14,143 - INFO - holdout 1 of 5
# 2019-06-28 15:25:14,310 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:14,316 - INFO - holdout 2 of 5
# 2019-06-28 15:25:14,490 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:14,496 - INFO - holdout 3 of 5
# 2019-06-28 15:25:14,656 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 100}
# 2019-06-28 15:25:14,667 - INFO - holdout 4 of 5
# 2019-06-28 15:25:14,845 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:14,851 - INFO - holdout 5 of 5
# 2019-06-28 15:25:15,024 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 100}
# 2019-06-28 15:25:15,030 - INFO - experiment finished
# 2019-06-28 15:25:15,030 - INFO - completed 8.57%
# 2019-06-28 15:25:15,030 - INFO - Considering ./data/classification/class-Decision_tree-tsne-length-5.json
# 2019-06-28 15:25:15,031 - INFO - does not exist, starting experiment
# 2019-06-28 15:25:15,031 - INFO - Found cached reduced data. Retrieving tsne-length
# 2019-06-28 15:25:15,034 - INFO - Checking alpha=0.20
# 2019-06-28 15:25:15,039 - INFO - holdout 1 of 5
# 2019-06-28 15:25:15,218 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:15,222 - INFO - holdout 2 of 5
# 2019-06-28 15:25:15,386 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:15,390 - INFO - holdout 3 of 5
# 2019-06-28 15:25:15,559 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:15,564 - INFO - holdout 4 of 5
# 2019-06-28 15:25:15,708 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:15,713 - INFO - holdout 5 of 5
# 2019-06-28 15:25:15,886 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50}
# 2019-06-28 15:25:15,889 - INFO - Checking alpha=0.40
# 2019-06-28 15:25:15,891 - INFO - holdout 1 of 5
# 2019-06-28 15:25:16,057 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:16,062 - INFO - holdout 2 of 5
# 2019-06-28 15:25:16,239 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50}
# 2019-06-28 15:25:16,246 - INFO - holdout 3 of 5
# 2019-06-28 15:25:16,390 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:16,394 - INFO - holdout 4 of 5
# 2019-06-28 15:25:16,557 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:16,562 - INFO - holdout 5 of 5
# 2019-06-28 15:25:16,728 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:16,732 - INFO - Checking alpha=0.50
# 2019-06-28 15:25:16,734 - INFO - holdout 1 of 5
# 2019-06-28 15:25:16,886 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:16,893 - INFO - holdout 2 of 5
# 2019-06-28 15:25:17,068 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:17,076 - INFO - holdout 3 of 5
# 2019-06-28 15:25:17,242 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 100}
# 2019-06-28 15:25:17,249 - INFO - holdout 4 of 5
# 2019-06-28 15:25:17,405 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:17,413 - INFO - holdout 5 of 5
# 2019-06-28 15:25:17,572 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:17,576 - INFO - Checking alpha=0.60
# 2019-06-28 15:25:17,578 - INFO - holdout 1 of 5
# 2019-06-28 15:25:17,739 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50}
# 2019-06-28 15:25:17,744 - INFO - holdout 2 of 5
# 2019-06-28 15:25:17,909 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:17,914 - INFO - holdout 3 of 5
# 2019-06-28 15:25:18,085 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:18,091 - INFO - holdout 4 of 5
# 2019-06-28 15:25:18,254 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:18,259 - INFO - holdout 5 of 5
# 2019-06-28 15:25:18,424 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:18,430 - INFO - Checking alpha=0.80
# 2019-06-28 15:25:18,433 - INFO - holdout 1 of 5
# 2019-06-28 15:25:18,591 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50}
# 2019-06-28 15:25:18,596 - INFO - holdout 2 of 5
# 2019-06-28 15:25:18,776 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:18,782 - INFO - holdout 3 of 5
# 2019-06-28 15:25:18,947 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 50}
# 2019-06-28 15:25:18,953 - INFO - holdout 4 of 5
# 2019-06-28 15:25:19,126 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:19,134 - INFO - holdout 5 of 5
# 2019-06-28 15:25:19,298 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:19,301 - INFO - Checking alpha=0.90
# 2019-06-28 15:25:19,305 - INFO - holdout 1 of 5
# 2019-06-28 15:25:19,467 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:19,475 - INFO - holdout 2 of 5
# 2019-06-28 15:25:19,653 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:19,660 - INFO - holdout 3 of 5
# 2019-06-28 15:25:19,826 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:19,832 - INFO - holdout 4 of 5
# 2019-06-28 15:25:19,998 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 100}
# 2019-06-28 15:25:20,003 - INFO - holdout 5 of 5
# 2019-06-28 15:25:20,162 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 100}
# 2019-06-28 15:25:20,167 - INFO - experiment finished
# 2019-06-28 15:25:20,168 - INFO - completed 9.29%
# 2019-06-28 15:25:20,168 - INFO - Considering ./data/classification/class-Decision_tree-tsne-length-10.json
# 2019-06-28 15:25:20,169 - INFO - does not exist, starting experiment
# 2019-06-28 15:25:20,169 - INFO - Found cached reduced data. Retrieving tsne-length
# 2019-06-28 15:25:20,173 - INFO - Checking alpha=0.20
# 2019-06-28 15:25:20,175 - INFO - holdout 1 of 5
# 2019-06-28 15:25:20,344 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:20,349 - INFO - holdout 2 of 5
# 2019-06-28 15:25:20,507 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:20,511 - INFO - holdout 3 of 5
# 2019-06-28 15:25:20,665 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:20,671 - INFO - holdout 4 of 5
# 2019-06-28 15:25:20,828 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:20,832 - INFO - holdout 5 of 5
# 2019-06-28 15:25:21,001 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:21,005 - INFO - Checking alpha=0.40
# 2019-06-28 15:25:21,007 - INFO - holdout 1 of 5
# 2019-06-28 15:25:21,168 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:21,172 - INFO - holdout 2 of 5
# 2019-06-28 15:25:21,335 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:21,343 - INFO - holdout 3 of 5
# 2019-06-28 15:25:21,504 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:21,508 - INFO - holdout 4 of 5
# 2019-06-28 15:25:21,675 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:21,680 - INFO - holdout 5 of 5
# 2019-06-28 15:25:21,849 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:21,856 - INFO - Checking alpha=0.50
# 2019-06-28 15:25:21,859 - INFO - holdout 1 of 5
# 2019-06-28 15:25:22,023 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:22,029 - INFO - holdout 2 of 5
# 2019-06-28 15:25:22,213 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 100}
# 2019-06-28 15:25:22,218 - INFO - holdout 3 of 5
# 2019-06-28 15:25:22,383 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:22,391 - INFO - holdout 4 of 5
# 2019-06-28 15:25:22,556 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:22,561 - INFO - holdout 5 of 5
# 2019-06-28 15:25:22,729 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:22,733 - INFO - Checking alpha=0.60
# 2019-06-28 15:25:22,736 - INFO - holdout 1 of 5
# 2019-06-28 15:25:22,905 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:22,911 - INFO - holdout 2 of 5
# 2019-06-28 15:25:23,085 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:23,090 - INFO - holdout 3 of 5
# 2019-06-28 15:25:23,254 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:23,258 - INFO - holdout 4 of 5
# 2019-06-28 15:25:23,425 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:23,432 - INFO - holdout 5 of 5
# 2019-06-28 15:25:23,591 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50}
# 2019-06-28 15:25:23,594 - INFO - Checking alpha=0.80
# 2019-06-28 15:25:23,596 - INFO - holdout 1 of 5
# 2019-06-28 15:25:23,755 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:23,761 - INFO - holdout 2 of 5
# 2019-06-28 15:25:23,929 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:23,934 - INFO - holdout 3 of 5
# 2019-06-28 15:25:24,106 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:24,111 - INFO - holdout 4 of 5
# 2019-06-28 15:25:24,280 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:24,286 - INFO - holdout 5 of 5
# 2019-06-28 15:25:24,443 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:24,447 - INFO - Checking alpha=0.90
# 2019-06-28 15:25:24,450 - INFO - holdout 1 of 5
# 2019-06-28 15:25:24,619 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:24,625 - INFO - holdout 2 of 5
# 2019-06-28 15:25:24,799 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:24,805 - INFO - holdout 3 of 5
# 2019-06-28 15:25:24,976 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:24,980 - INFO - holdout 4 of 5
# 2019-06-28 15:25:25,154 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:25,159 - INFO - holdout 5 of 5
# 2019-06-28 15:25:25,332 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:25,337 - INFO - experiment finished
# 2019-06-28 15:25:25,338 - INFO - completed 10.00%
# 2019-06-28 15:25:25,338 - INFO - Considering ./data/classification/class-Decision_tree-tsne-length-30.json
# 2019-06-28 15:25:25,339 - INFO - does not exist, starting experiment
# 2019-06-28 15:25:25,339 - INFO - Found cached reduced data. Retrieving tsne-length
# 2019-06-28 15:25:25,344 - INFO - Checking alpha=0.20
# 2019-06-28 15:25:25,347 - INFO - holdout 1 of 5
# 2019-06-28 15:25:25,503 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:25,508 - INFO - holdout 2 of 5
# 2019-06-28 15:25:25,680 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:25,686 - INFO - holdout 3 of 5
# 2019-06-28 15:25:25,849 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:25,855 - INFO - holdout 4 of 5
# 2019-06-28 15:25:26,025 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:26,031 - INFO - holdout 5 of 5
# 2019-06-28 15:25:26,213 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:26,218 - INFO - Checking alpha=0.40
# 2019-06-28 15:25:26,221 - INFO - holdout 1 of 5
# 2019-06-28 15:25:26,405 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 100}
# 2019-06-28 15:25:26,412 - INFO - holdout 2 of 5
# 2019-06-28 15:25:26,589 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:26,594 - INFO - holdout 3 of 5
# 2019-06-28 15:25:26,769 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:26,775 - INFO - holdout 4 of 5
# 2019-06-28 15:25:26,949 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:26,955 - INFO - holdout 5 of 5
# 2019-06-28 15:25:27,136 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:27,141 - INFO - Checking alpha=0.50
# 2019-06-28 15:25:27,144 - INFO - holdout 1 of 5
# 2019-06-28 15:25:27,317 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:27,325 - INFO - holdout 2 of 5
# 2019-06-28 15:25:27,500 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:27,505 - INFO - holdout 3 of 5
# 2019-06-28 15:25:27,690 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:27,696 - INFO - holdout 4 of 5
# 2019-06-28 15:25:27,875 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:27,881 - INFO - holdout 5 of 5
# 2019-06-28 15:25:28,068 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:28,074 - INFO - Checking alpha=0.60
# 2019-06-28 15:25:28,077 - INFO - holdout 1 of 5
# 2019-06-28 15:25:28,255 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:28,261 - INFO - holdout 2 of 5
# 2019-06-28 15:25:28,434 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:28,441 - INFO - holdout 3 of 5
# 2019-06-28 15:25:28,616 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:28,622 - INFO - holdout 4 of 5
# 2019-06-28 15:25:28,804 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:28,810 - INFO - holdout 5 of 5
# 2019-06-28 15:25:28,979 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:28,983 - INFO - Checking alpha=0.80
# 2019-06-28 15:25:28,987 - INFO - holdout 1 of 5
# 2019-06-28 15:25:29,168 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 100}
# 2019-06-28 15:25:29,174 - INFO - holdout 2 of 5
# 2019-06-28 15:25:29,356 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50}
# 2019-06-28 15:25:29,362 - INFO - holdout 3 of 5
# 2019-06-28 15:25:29,524 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:29,530 - INFO - holdout 4 of 5
# 2019-06-28 15:25:29,703 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:29,709 - INFO - holdout 5 of 5
# 2019-06-28 15:25:29,869 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None}
# 2019-06-28 15:25:29,875 - INFO - Checking alpha=0.90
# 2019-06-28 15:25:29,878 - INFO - holdout 1 of 5
# 2019-06-28 15:25:30,044 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:30,050 - INFO - holdout 2 of 5
# 2019-06-28 15:25:30,234 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None}
# 2019-06-28 15:25:30,240 - INFO - holdout 3 of 5
# 2019-06-28 15:25:30,416 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:30,421 - INFO - holdout 4 of 5
# 2019-06-28 15:25:30,593 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 50}
# 2019-06-28 15:25:30,597 - INFO - holdout 5 of 5
# 2019-06-28 15:25:30,787 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None}
# 2019-06-28 15:25:30,791 - INFO - experiment finished
# 2019-06-28 15:25:30,792 - INFO - completed 10.71%
# 2019-06-28 15:25:30,792 - INFO - Considering ./data/classification/class-Decision_tree-tsne-levenshtein-2.json
# 2019-06-28 15:25:30,793 - INFO - already exists, skipping
# 2019-06-28 15:25:30,793 - INFO - completed 11.43%
# 2019-06-28 15:25:30,793 - INFO - Considering ./data/classification/class-Decision_tree-tsne-levenshtein-3.json
# 2019-06-28 15:25:30,794 - INFO - already exists, skipping
# 2019-06-28 15:25:30,794 - INFO - completed 12.14%
# 2019-06-28 15:25:30,795 - INFO - Considering ./data/classification/class-Decision_tree-tsne-levenshtein-5.json
# 2019-06-28 15:25:30,795 - INFO - already exists, skipping
# 2019-06-28 15:25:30,795 - INFO - completed 12.86%
# 2019-06-28 15:25:30,796 - INFO - Considering ./data/classification/class-Decision_tree-tsne-levenshtein-10.json
# 2019-06-28 15:25:30,797 - INFO - already exists, skipping
# 2019-06-28 15:25:30,797 - INFO - completed 13.57%
# 2019-06-28 15:25:30,798 - INFO - Considering ./data/classification/class-Decision_tree-tsne-levenshtein-30.json
# 2019-06-28 15:25:30,798 - INFO - already exists, skipping
# 2019-06-28 15:25:30,799 - INFO - completed 14.29%
# 2019-06-28 15:25:30,799 - INFO - Considering ./data/classification/class-Random_forest-tsne-hamming-2.json
# 2019-06-28 15:25:30,801 - INFO - does not exist, starting experiment
# 2019-06-28 15:25:30,801 - INFO - Found cached reduced data. Retrieving tsne-hamming
# 2019-06-28 15:25:30,808 - INFO - Checking alpha=0.20
# 2019-06-28 15:25:30,812 - INFO - holdout 1 of 5
# 2019-06-28 15:26:27,453 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:26:27,464 - INFO - holdout 2 of 5
# 2019-06-28 15:27:24,875 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:27:24,884 - INFO - holdout 3 of 5
# 2019-06-28 15:28:22,670 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 10}
# 2019-06-28 15:28:22,686 - INFO - holdout 4 of 5
# 2019-06-28 15:29:21,545 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:29:21,554 - INFO - holdout 5 of 5
# 2019-06-28 15:30:20,330 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:30:20,338 - INFO - Checking alpha=0.40
# 2019-06-28 15:30:20,341 - INFO - holdout 1 of 5
# 2019-06-28 15:31:17,489 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:31:17,498 - INFO - holdout 2 of 5
# 2019-06-28 15:32:17,020 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:32:17,030 - INFO - holdout 3 of 5
# 2019-06-28 15:33:16,241 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2, 'n_estimators': 50}
# 2019-06-28 15:33:16,293 - INFO - holdout 4 of 5
# 2019-06-28 15:34:14,374 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:34:14,383 - INFO - holdout 5 of 5
# 2019-06-28 15:35:12,921 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 10}
# 2019-06-28 15:35:12,934 - INFO - Checking alpha=0.50
# 2019-06-28 15:35:12,937 - INFO - holdout 1 of 5
# 2019-06-28 15:36:13,678 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:36:13,687 - INFO - holdout 2 of 5
# 2019-06-28 15:37:14,294 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:37:14,303 - INFO - holdout 3 of 5
# 2019-06-28 15:38:12,660 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 10}
# 2019-06-28 15:38:12,675 - INFO - holdout 4 of 5
# 2019-06-28 15:39:11,477 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:39:11,486 - INFO - holdout 5 of 5
# 2019-06-28 15:40:10,254 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 5, 'n_estimators': 5}
# 2019-06-28 15:40:10,261 - INFO - Checking alpha=0.60
# 2019-06-28 15:40:10,264 - INFO - holdout 1 of 5
# 2019-06-28 15:41:09,305 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 10}
# 2019-06-28 15:41:09,320 - INFO - holdout 2 of 5
# 2019-06-28 15:42:04,378 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:42:04,387 - INFO - holdout 3 of 5
# 2019-06-28 15:42:57,159 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:42:57,167 - INFO - holdout 4 of 5
# 2019-06-28 15:43:50,497 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:43:50,507 - INFO - holdout 5 of 5
# 2019-06-28 15:44:49,073 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:44:49,081 - INFO - Checking alpha=0.80
# 2019-06-28 15:44:49,084 - INFO - holdout 1 of 5
# 2019-06-28 15:45:46,341 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:45:46,350 - INFO - holdout 2 of 5
# 2019-06-28 15:46:44,463 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'n_estimators': 5}
# 2019-06-28 15:46:44,472 - INFO - holdout 3 of 5
# 2019-06-28 15:47:39,666 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None, 'n_estimators': 10}
# 2019-06-28 15:47:39,682 - INFO - holdout 4 of 5
# 2019-06-28 15:48:30,756 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:48:30,764 - INFO - holdout 5 of 5
# 2019-06-28 15:49:21,421 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:49:21,427 - INFO - Checking alpha=0.90
# 2019-06-28 15:49:21,430 - INFO - holdout 1 of 5
# 2019-06-28 15:50:12,798 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:50:12,807 - INFO - holdout 2 of 5
# 2019-06-28 15:51:03,450 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None, 'n_estimators': 200}
# 2019-06-28 15:51:03,639 - INFO - holdout 3 of 5
# 2019-06-28 15:51:54,163 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 10}
# 2019-06-28 15:51:54,176 - INFO - holdout 4 of 5
# 2019-06-28 15:52:44,816 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2, 'n_estimators': 50}
# 2019-06-28 15:52:44,862 - INFO - holdout 5 of 5
# 2019-06-28 15:53:36,083 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'max_leaf_nodes': 50, 'n_estimators': 5}
# 2019-06-28 15:53:36,090 - INFO - experiment finished
# 2019-06-28 15:53:36,090 - INFO - completed 15.00%
# 2019-06-28 15:53:36,091 - INFO - Considering ./data/classification/class-Random_forest-tsne-hamming-3.json
# 2019-06-28 15:53:36,091 - INFO - does not exist, starting experiment
# 2019-06-28 15:53:36,092 - INFO - Found cached reduced data. Retrieving tsne-hamming
# 2019-06-28 15:53:36,095 - INFO - Checking alpha=0.20
# 2019-06-28 15:53:36,098 - INFO - holdout 1 of 5
# 2019-06-28 15:54:33,364 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:54:33,373 - INFO - holdout 2 of 5
# 2019-06-28 15:55:30,638 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:55:30,647 - INFO - holdout 3 of 5
# 2019-06-28 15:56:29,109 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:56:29,118 - INFO - holdout 4 of 5
# 2019-06-28 15:57:27,998 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:57:28,011 - INFO - holdout 5 of 5
# 2019-06-28 15:58:21,284 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 15:58:21,291 - INFO - Checking alpha=0.40
# 2019-06-28 15:58:21,294 - INFO - holdout 1 of 5
# 2019-06-28 15:59:14,833 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2, 'n_estimators': 100}
# 2019-06-28 15:59:14,924 - INFO - holdout 2 of 5
# 2019-06-28 16:00:06,395 - INFO - Learning with best hyperparams: {'criterion': 'entropy', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': 50, 'n_estimators': 100}
# 2019-06-28 16:00:06,507 - INFO - holdout 3 of 5
# 2019-06-28 16:00:58,257 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 16:00:58,265 - INFO - holdout 4 of 5
# 2019-06-28 16:01:56,794 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 2, 'n_estimators': 10}
# 2019-06-28 16:01:56,810 - INFO - holdout 5 of 5
# 2019-06-28 16:02:56,704 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 100}
# 2019-06-28 16:02:56,817 - INFO - Checking alpha=0.50
# 2019-06-28 16:02:56,819 - INFO - holdout 1 of 5
# 2019-06-28 16:03:56,610 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 16:03:56,619 - INFO - holdout 2 of 5
# 2019-06-28 16:04:54,959 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 16:04:54,968 - INFO - holdout 3 of 5
# 2019-06-28 16:05:47,945 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 10}
# 2019-06-28 16:05:47,958 - INFO - holdout 4 of 5
# 2019-06-28 16:06:39,093 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 50}
# 2019-06-28 16:06:39,145 - INFO - holdout 5 of 5
# 2019-06-28 16:07:30,012 - INFO - Learning with best hyperparams: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 2, 'n_estimators': 5}
# 2019-06-28 16:07:30,020 - INFO - Checking alpha=0.60
# 2019-06-28 16:07:30,022 - INFO - holdout 1 of 5
# ...
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:39,318 - INFO - Learning with best hyperparams: {'C': 1, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:36:39,380 - INFO - holdout 3 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:40,149 - INFO - Learning with best hyperparams: {'C': 10, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:36:40,224 - INFO - holdout 4 of 5
# 2019-06-29 00:36:40,970 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:41,023 - INFO - holdout 5 of 5
# 2019-06-29 00:36:41,789 - INFO - Learning with best hyperparams: {'C': 10, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:36:41,857 - INFO - experiment finished
# 2019-06-29 00:36:41,858 - INFO - completed 95.71%
# 2019-06-29 00:36:41,858 - INFO - Considering ./data/classification/class-SVC_(gaussian)-tsne-length-30.json
# 2019-06-29 00:36:41,859 - INFO - does not exist, starting experiment
# 2019-06-29 00:36:41,859 - INFO - Found cached reduced data. Retrieving tsne-length
# 2019-06-29 00:36:41,863 - INFO - Checking alpha=0.20
# 2019-06-29 00:36:41,866 - INFO - holdout 1 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:42,585 - INFO - Learning with best hyperparams: {'C': 1, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:36:42,650 - INFO - holdout 2 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:43,359 - INFO - Learning with best hyperparams: {'C': 1, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:36:43,419 - INFO - holdout 3 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:44,123 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:44,169 - INFO - holdout 4 of 5
# 2019-06-29 00:36:44,841 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:44,887 - INFO - holdout 5 of 5
# 2019-06-29 00:36:45,559 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:45,603 - INFO - Checking alpha=0.40
# 2019-06-29 00:36:45,605 - INFO - holdout 1 of 5
# 2019-06-29 00:36:46,337 - INFO - Learning with best hyperparams: {'C': 1, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:36:46,398 - INFO - holdout 2 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:47,117 - INFO - Learning with best hyperparams: {'C': 1, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:36:47,178 - INFO - holdout 3 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:47,899 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:47,945 - INFO - holdout 4 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:48,672 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:48,718 - INFO - holdout 5 of 5
# 2019-06-29 00:36:49,421 - INFO - Learning with best hyperparams: {'C': 10, 'gamma': 30, 'kernel': 'rbf'}
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:49,494 - INFO - Checking alpha=0.50
# 2019-06-29 00:36:49,496 - INFO - holdout 1 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:50,223 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:50,275 - INFO - holdout 2 of 5
# 2019-06-29 00:36:50,965 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:51,017 - INFO - holdout 3 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:51,714 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:51,760 - INFO - holdout 4 of 5
# 2019-06-29 00:36:52,448 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:52,496 - INFO - holdout 5 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:53,214 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:53,259 - INFO - Checking alpha=0.60
# 2019-06-29 00:36:53,261 - INFO - holdout 1 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:53,973 - INFO - Learning with best hyperparams: {'C': 1, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:36:54,026 - INFO - holdout 2 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:54,740 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:54,794 - INFO - holdout 3 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:55,518 - INFO - Learning with best hyperparams: {'C': 1, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:36:55,577 - INFO - holdout 4 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:56,310 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:56,357 - INFO - holdout 5 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:57,077 - INFO - Learning with best hyperparams: {'C': 10, 'gamma': 30, 'kernel': 'rbf'}
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:57,147 - INFO - Checking alpha=0.80
# 2019-06-29 00:36:57,150 - INFO - holdout 1 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:57,900 - INFO - Learning with best hyperparams: {'C': 1, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:36:57,959 - INFO - holdout 2 of 5
# 2019-06-29 00:36:58,697 - INFO - Learning with best hyperparams: {'C': 1, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:36:58,758 - INFO - holdout 3 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:36:59,498 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:36:59,546 - INFO - holdout 4 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:37:00,285 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:37:00,333 - INFO - holdout 5 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:37:01,077 - INFO - Learning with best hyperparams: {'C': 10, 'gamma': 10, 'kernel': 'rbf'}
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:37:01,157 - INFO - Checking alpha=0.90
# 2019-06-29 00:37:01,160 - INFO - holdout 1 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:37:01,892 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:37:01,942 - INFO - holdout 2 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:37:02,684 - INFO - Learning with best hyperparams: {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 2019-06-29 00:37:02,734 - INFO - holdout 3 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:37:03,516 - INFO - Learning with best hyperparams: {'C': 10, 'gamma': 10, 'kernel': 'rbf'}
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:37:03,593 - INFO - holdout 4 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:37:04,366 - INFO - Learning with best hyperparams: {'C': 10, 'gamma': 10, 'kernel': 'rbf'}
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:37:04,445 - INFO - holdout 5 of 5
# /home/malchiodi/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:241: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 2019-06-29 00:37:05,205 - INFO - Learning with best hyperparams: {'C': 1, 'gamma': 30, 'kernel': 'rbf'}
# 2019-06-29 00:37:05,271 - INFO - experiment finished
# 2019-06-29 00:37:05,272 - INFO - completed 96.43%
# 2019-06-29 00:37:05,272 - INFO - Considering ./data/classification/class-SVC_(gaussian)-tsne-levenshtein-2.json
# 2019-06-29 00:37:05,272 - INFO - already exists, skipping
# 2019-06-29 00:37:05,273 - INFO - completed 97.14%
# 2019-06-29 00:37:05,273 - INFO - Considering ./data/classification/class-SVC_(gaussian)-tsne-levenshtein-3.json
# 2019-06-29 00:37:05,273 - INFO - already exists, skipping
# 2019-06-29 00:37:05,274 - INFO - completed 97.86%
# 2019-06-29 00:37:05,274 - INFO - Considering ./data/classification/class-SVC_(gaussian)-tsne-levenshtein-5.json
# 2019-06-29 00:37:05,275 - INFO - already exists, skipping
# 2019-06-29 00:37:05,276 - INFO - completed 98.57%
# 2019-06-29 00:37:05,276 - INFO - Considering ./data/classification/class-SVC_(gaussian)-tsne-levenshtein-10.json
# 2019-06-29 00:37:05,276 - INFO - already exists, skipping
# 2019-06-29 00:37:05,277 - INFO - completed 99.29%
# 2019-06-29 00:37:05,277 - INFO - Considering ./data/classification/class-SVC_(gaussian)-tsne-levenshtein-30.json
# 2019-06-29 00:37:05,277 - INFO - already exists, skipping
# 2019-06-29 00:37:05,278 - INFO - completed 100.00%
